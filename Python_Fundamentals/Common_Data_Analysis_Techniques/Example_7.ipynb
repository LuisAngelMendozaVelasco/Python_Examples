# %% [markdown]
# # Fit a Line

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
x = np.arange(1, 9)
y = np.array([7.20, 12.00, 17.60, 18.1, 23.50, 30.20, 32.40, 38.00])

# %%
plt.figure()
plt.scatter(x, y, marker="o")
plt.show()

# %% [markdown]
# The [polyfit()](https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html#numpy-polyfit) function finds the coefficients of the best fit n-th degree polynomial of yData in terms of xData.

# %%
c = np.polyfit(x, y, 1)
c
# Out:
# array([4.2952381 , 3.04642857])

# %% [markdown]
# The [polyval()](https://numpy.org/doc/stable/reference/generated/numpy.polyval.html#numpy-polyval) function evaluates a polynomial (given by coefficients cf) at the points xEval.

# %%
y_fit = np.polyval(c, x)
y_fit
# Out:
# array([ 7.34166667, 11.63690476, 15.93214286, 20.22738095, 24.52261905,
#        28.81785714, 33.11309524, 37.40833333])

# %%
plt.figure()
plt.scatter(x, y, marker="o")
plt.plot(x, y_fit, color='r')
plt.show()
