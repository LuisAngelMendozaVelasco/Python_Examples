# %% [markdown]
# # Plot Electricity Usage

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style("whitegrid")

# %%
dates = pd.read_excel("./data/electricityData.xlsx", sheet_name="dates", header=None, converters={0: pd.to_datetime})
sectors = pd.read_excel("./data/electricityData.xlsx", sheet_name="sectors", header=None, converters={0: str})
usage = pd.read_excel("./data/electricityData.xlsx", sheet_name="usage", header=None)

# %%
plt.figure()
plt.plot(dates, usage)
plt.legend(sectors.iloc[0])
plt.show()

# %%
plt.figure()
sns.pairplot(usage)
plt.show()

# %% [markdown]
# We can see in the scatter plots that some columns appear more correlated than others. We can quantify these correlations.

# %%
usage.corr()
# Out:
#           0         1         2         3
# 0  1.000000  0.824285  0.130026  0.951857
# 1  0.824285  1.000000  0.159067  0.926796
# 2  0.130026  0.159067  1.000000  0.293800
# 3  0.951857  0.926796  0.293800  1.000000
