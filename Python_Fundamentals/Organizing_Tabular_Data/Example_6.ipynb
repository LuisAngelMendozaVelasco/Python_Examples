# %% [markdown]
# # Update Table Variable Names

# %%
import pandas as pd

# %%
teamInfo = pd.read_csv("./data/EPLteams.csv", encoding='latin-1')
teamInfo
# Out:
#                     Team  Payroll_M__                Manager ManagerHireDate  \
# 0         Leicester City         48.2        Claudio Ranieri      07/13/2015
# 1                Arsenal        192.0          Arsène Wenger      10/01/1996
# 2      Tottenham Hotspur        110.5    Mauricio Pochettino      05/27/2014
# 3        Manchester City        193.8      Manuel Pellegrini      06/14/2013
# 4      Manchester United        203.0         Louis van Gaal      07/14/2014
# 5            Southampton         59.5          Ronald Koeman      06/16/2014
# 6        West Ham United         69.5           Slaven Bili?      06/09/2015
# 7              Liverpool        152.0           Jürgen Klopp      10/08/2015
# 8             Stoke City         72.3            Mark Hughes      05/30/2013
# 9                Chelsea        215.6           Guus Hiddink      12/19/2015
# 10               Everton         74.7         David Unsworth      05/12/2016
# ...

# %%
teamInfo.columns
# Out:
# Index(['Team', 'Payroll_M__', 'Manager', 'ManagerHireDate',
#        'ManagerNationality'],
#       dtype='object')

# %%
teamInfo.rename(columns={'Payroll_M__': 'Payroll'}, inplace=True)
teamInfo
# Out:
#                     Team  Payroll                Manager ManagerHireDate  \
# 0         Leicester City     48.2        Claudio Ranieri      07/13/2015
# 1                Arsenal    192.0          Arsène Wenger      10/01/1996
# 2      Tottenham Hotspur    110.5    Mauricio Pochettino      05/27/2014
# 3        Manchester City    193.8      Manuel Pellegrini      06/14/2013
# 4      Manchester United    203.0         Louis van Gaal      07/14/2014
# 5            Southampton     59.5          Ronald Koeman      06/16/2014
# 6        West Ham United     69.5           Slaven Bili?      06/09/2015
# 7              Liverpool    152.0           Jürgen Klopp      10/08/2015
# 8             Stoke City     72.3            Mark Hughes      05/30/2013
# 9                Chelsea    215.6           Guus Hiddink      12/19/2015
# 10               Everton     74.7         David Unsworth      05/12/2016
# 11          Swansea City     51.0     Francesco Guidolin      01/18/2016
# ...
