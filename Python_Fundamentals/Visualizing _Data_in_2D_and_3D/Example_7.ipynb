# %% [markdown]
# # Specify Colors

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
x = np.arange(0, 2*np.pi+0.1, 0.1)
y = np.sin(x)

# %%
plt.figure()
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# For eight specific colors, you can refer to them by name or a single letter abbreviation:
# * red (r)
# * green (g)
# * blue (b)
# * black (k)
# * magenta (m)
# * yellow (y)
# * cyan (c)
# * white (w)

# %%
plt.figure()
plt.plot(x, y, color='k')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# We can specify over ten million other colors with a 3-element vector of red-green-blue (RGB) values. The three elements correspond to the fractional red, green, and blue parts of the color composition. The values in this RGB range from 0 to 1.

# %%
plt.figure()
plt.plot(x, y, color=[0.5, 0.6, 0])
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# We can use either text codes or RGB vectors when specifying any color property.

# %%
plt.figure()
plt.plot(x, y, color=[0.6, 0.2, 0.8], marker='o', markeredgecolor='c')
plt.xlabel("x")
plt.ylabel("y")
plt.show()
